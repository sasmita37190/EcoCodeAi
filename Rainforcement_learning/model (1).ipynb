# %%
import pandas as pd
ddf = pd.read_csv("filename.csv")
ddf
# Out:
#       CPU_Time(ms)  Memory(KB)  Energy(kWh)  Carbon_Emission(gCO₂)  \
# 0         0.575556    0.981166     0.575556               0.575556
# 1         0.940000    0.958705     0.940000               0.940000
# 2         0.863333    0.686523     0.863333               0.863333
# 3         0.728889    0.294922     0.728889               0.728889
# 4         0.450000    0.499442     0.450000               0.450000
# ...            ...         ...          ...                    ...
# 9995      0.804444    0.573661     0.804444               0.804444
# 9996      0.946667    0.707868     0.946667               0.946667
# 9997      0.180000    0.620675     0.180000               0.180000
# 9998      0.816667    0.993862     0.816667               0.816667
# 9999      0.614444    0.485910     0.614444               0.614444
#
#       Efficiency_Label                                          Functions  \
# 0                    1                                    ['nested_loop']
# 1                    1                                    ['bubble_sort']
# 2                    0                                     ['merge_sort']
# 3                    0                                       ['find_max']
# 4                    1                                    ['nested_loop']
# ...                ...                                                ...
# 9995                 1                                     ['bubbleSort']
# 9996                 0                  ['sumArray', 'anonymous_arrow_0']
# 9997                 1  ['nestedLoop', 'anonymous_arrow_0', 'anonymous...
# 9998                 0                     ['quickSort', 'left', 'right']
# 9999                 0                                        ['findMax']
#
#       Loops                                      Variables  Control_Flows  \
# 0         2                     ['print', 'arr', 'i', 'j']              0
# 1         2         ['n', 'i', 'len', 'range', 'arr', 'j']              1
# 2         0  ['len', 'merge_sort', 'arr', 'L', 'R', 'mid']              1
# 3         1                        ['max_val', 'arr', 'i']              1
# 4         2                     ['print', 'arr', 'i', 'j']              0
# ...     ...                                            ...            ...
# 9995      2                                ['n', 'i', 'j']              1
# 9996      0                                             []              0
# 9997      0                                             []              0
# 9998      0                     ['pivot', 'left', 'right']              1
# 9999      0                                             []              0
#
#       Language_JavaScript  Language_Python
# 0                     0.0              1.0
# 1                     0.0              1.0
# 2                     0.0              1.0
# 3                     0.0              1.0
# 4                     0.0              1.0
# ...                   ...              ...
# 9995                  1.0              0.0
# 9996                  1.0              0.0
# 9997                  1.0              0.0
# 9998                  1.0              0.0
# 9999                  1.0              0.0
#
# [10000 rows x 11 columns]

# %%
  import ast

  def analyze_python_code(code):
      tree = ast.parse(code)
      functions = []
      loops = []
      variables = set()
      control_flows = []

      for node in ast.walk(tree):
          if isinstance(node, ast.FunctionDef):
              functions.append(node.name)
          elif isinstance(node, (ast.For, ast.While)):
              loops.append(node)
          elif isinstance(node, ast.Name):
              variables.add(node.id)
          elif isinstance(node, (ast.If, ast.Try)):
              control_flows.append(node)

      return {
          'functions': functions,
          'loops': len(loops),
          'variables': list(variables),
          'control_flows': len(control_flows)
      }

# %%
import re
import pandas as pd

def analyze_javascript_code(code):
    """
    Analyze JavaScript code to extract functions, loops, variables, and control flows
    using regular expressions without any external dependencies.
    """
    try:
        # Find function declarations like "function name() {}"
        function_decls = re.findall(r'function\s+(\w+)', code)
        
        # Find function expressions like "const name = function() {}" or "const name = () => {}"
        func_expressions = re.findall(r'(?:var|let|const)\s+(\w+)\s*=\s*function', code)
        arrow_funcs = re.findall(r'(?:var|let|const)\s+(\w+)\s*=\s*(?:\([^)]*\)|[^=]*)\s*=>', code)
        
        # Combine all functions
        functions = function_decls + func_expressions + arrow_funcs
        
        # Anonymous arrow functions that we can't easily get the name of
        anonymous_arrows = len(re.findall(r'=>', code)) - len(arrow_funcs)
        for i in range(anonymous_arrows):
            functions.append(f"anonymous_arrow_{i}")
        
        # Count loops: for, while, do-while
        for_loops = len(re.findall(r'\bfor\s*\(', code))
        while_loops = len(re.findall(r'\bwhile\s*\(', code))
        do_while_loops = len(re.findall(r'\bdo\s*\{', code))
        loops = for_loops + while_loops + do_while_loops
        
        # Find variable declarations
        var_declarations = re.findall(r'\b(?:var|let|const)\s+(\w+)', code)
        
        # Count control flow statements
        if_statements = len(re.findall(r'\bif\s*\(', code))
        switch_statements = len(re.findall(r'\bswitch\s*\(', code))
        try_statements = len(re.findall(r'\btry\s*\{', code))
        ternary_operators = len(re.findall(r'\?\s*[^:]+\s*:', code))
        control_flows = if_statements + switch_statements + try_statements + ternary_operators
        
        return {
            'functions': functions,
            'loops': loops,
            'variables': var_declarations,
            'control_flows': control_flows
        }
    except Exception as e:
        return {
            'error': str(e),
            'functions': [],
            'loops': 0,
            'variables': [],
            'control_flows': 0
        }

# %%
  import tokenize
  from io import BytesIO

  def tokenize_python_code(code):
      tokens = []
      reader = BytesIO(code.encode('utf-8')).readline
      for tok in tokenize.tokenize(reader):
          tokens.append((tokenize.tok_name[tok.type], tok.string))
      return tokens

# %%
import re
from io import StringIO
import pandas as pd

def tokenize_javascript_code(code):
    """
    A JavaScript tokenizer implemented in Python that provides
    output similar to Python's tokenize module.
    Returns a list of (token_type, token_value) tuples.
    """
    # Start with encoding token
    tokens = [('ENCODING', 'utf-8')]
    
    # Define patterns for different token types
    patterns = [
        # Comments
        (r'\/\/.*?$|\/\*[\s\S]*?\*\/', 'COMMENT'),
        
        # Strings
        (r'"(?:\\.|[^"\\])*"', 'STRING'),
        (r"'(?:\\.|[^'\\])*'", 'STRING'),
        (r"`(?:\\.|[^`\\])*`", 'STRING'),
        
        # Numbers
        (r'\b\d+(?:\.\d+)?(?:[eE][+-]?\d+)?\b', 'NUMBER'),
        
        # Keywords
        (r'\b(var|let|const|function|if|else|for|while|do|switch|case|break|continue|return|new|try|catch|finally|throw|class|this|super|import|export|from|as|async|await|yield|delete|typeof|instanceof|in|of|void|default|extends|implements|interface|package|private|protected|public|static)\b', 'KEYWORD'),
        
        # Operators
        (r'=>|===|!==|==|!=|>=|<=|\+\+|--|&&|\|\||\+=|-=|\*=|/=|%=|\*\*=|<<=|>>=|>>>=|&=|\|=|\^=', 'OP'),
        (r'[+\-*/%&|^~<>=!?:]', 'OP'),
        
        # Separators
        (r'[\[\](){}]', 'OP'),
        (r';', 'OP'),
        (r',', 'OP'),
        (r'\.', 'OP'),
        
        # Identifiers (must come after keywords)
        (r'[a-zA-Z_$][a-zA-Z0-9_$]*', 'NAME'),
        
        # Newlines
        (r'\n', 'NL'),
        
        # Whitespace
        (r'[ \t\r]+', 'WHITESPACE'),
    ]
    
    # Function to find the next token
    def find_next_token(text, pos):
        for pattern, token_type in patterns:
            regex = re.compile(pattern)
            match = regex.match(text, pos)
            if match:
                return token_type, match.group(0), match.end()
        
        # If no pattern matches, return just the current character
        if pos < len(text):
            return 'OP', text[pos], pos + 1
        return None, None, pos
    
    # Process the code character by character
    pos = 0
    while pos < len(code):
        token_type, token_value, new_pos = find_next_token(code, pos)
        if token_type:
            # Skip whitespace tokens but keep newlines
            if token_type != 'WHITESPACE':
                # Convert keywords to NAME to match Python's tokenizer behavior
                if token_type == 'KEYWORD':
                    token_type = 'NAME'
                tokens.append((token_type, token_value))
            pos = new_pos
        else:
            break
    
    # Add the ENDMARKER token
    tokens.append(('NEWLINE', ''))
    tokens.append(('ENDMARKER', ''))
    
    return tokens

# Example usage function
def tokenize_code(df):
    lang = df.iloc[9, 0]
    code = df.iloc[0, 1]
    
    if lang == "JavaScript":
        tokens = tokenize_javascript_code(code)
        return tokens
    elif lang == "Python":
        import tokenize
        from io import BytesIO
        
        def tokenize_python_code(code):
            tokens = []
            reader = BytesIO(code.encode('utf-8')).readline
            for tok in tokenize.tokenize(reader):
                tokens.append((tokenize.tok_name[tok.type], tok.string))
            return tokens
        
        tokens = tokenize_python_code(code)
        return tokens
    else:
        return [("ERROR", f"Unsupported language: {lang}")]

# %%
import pandas as pd
import ast
import re

# Load dataset from final_dataset.csv
ddf = pd.read_csv(r"C:\Users\Deba Prakash\Desktop\Model Traning\final_dataset.csv")

# Check if required columns exist
required_columns = {'Language', 'Code'}
if not required_columns.issubset(ddf.columns):
    raise ValueError(f"Missing required columns: {required_columns - set(ddf.columns)}")

# Function to analyze Python code
def analyze_python_code(code):
    try:
        tree = ast.parse(code)
        functions, loops, variables, control_flows = [], [], set(), []

        for node in ast.walk(tree):
            if isinstance(node, ast.FunctionDef):
                functions.append(node.name)
            elif isinstance(node, (ast.For, ast.While)):
                loops.append(node)
            elif isinstance(node, ast.Name):
                variables.add(node.id)
            elif isinstance(node, (ast.If, ast.Try)):
                control_flows.append(node)

        return {
            'Functions': functions,
            'Loops': len(loops),
            'Variables': list(variables),
            'Control_Flows': len(control_flows)
        }
    except Exception:
        return {'functions': [], 'loops': 0, 'variables': [], 'control_flows': 0}

# Function to analyze JavaScript code
def analyze_javascript_code(code):
    try:
        functions = re.findall(r'function\s+(\w+)\s*\(', code)
        loops = len(re.findall(r'\b(for|while)\b', code))
        variables = re.findall(r'\b(var|let|const)\s+(\w+)', code)
        control_flows = len(re.findall(r'\b(if|else|switch|case|try|catch)\b', code))
        return {
            'functions': functions,
            'loops': loops,
            'variables': [var[1] for var in variables],
            'control_flows': control_flows
        }
    except Exception:
        return {'functions': [], 'loops': 0, 'variables': [], 'control_flows': 0}

# Function to tokenize code
def tokenize_code(code):
    return re.findall(r'\b\w+\b', code) if isinstance(code, str) else []

# Function to analyze a row
def analyze_code(row):
    if row['Language'] == 'Python':
        analysis = analyze_python_code(row['Code'])
        tokens = tokenize_code(row['Code'])
    elif row['Language'] == 'JavaScript':
        analysis = analyze_javascript_code(row['Code'])
        tokens = tokenize_code(row['Code'])
    else:
        analysis = {'functions': [], 'loops': 0, 'variables': [], 'control_flows': 0}
        tokens = []
    
    return {
        'Functions': analysis.get('functions', []),
        'Loops': analysis.get('loops', 0),
        'Variables': analysis.get('variables', []),
        'Control_Flows': analysis.get('control_flows', 0),
        'Tokens': tokens
    }

# Apply function to DataFrame
analysis_results = ddf.apply(analyze_code, axis=1)

# Update existing columns or add new ones
ddf.update(analysis_results)

# Display the updated DataFrame
print(ddf.head())
# Out:
#   Language                                               Code  CPU_Time(ms)  \
# 0   Python  def nested_loop(arr):\n    for i in arr:\n    ...           618
# 1   Python  def bubble_sort(arr):\n    n = len(arr)\n    f...           946
# 2   Python  def merge_sort(arr):\n    if len(arr) > 1:\n  ...           877
# 3   Python  def find_max(arr):\n    max_val = arr[0]\n    ...           756
# 4   Python  def nested_loop(arr):\n    for i in arr:\n    ...           505
#
#    Memory(KB)  Energy(kWh)  Carbon_Emission(gCO₂)  Efficiency_Label  \
# 0        8057     0.017167               6.866667                 1
# 1        7896     0.026278              10.511111                 1
# 2        5945     0.024361               9.744444                 0
# 3        3138     0.021000               8.400000                 0
# 4        4604     0.014028               5.611111                 1
#
#          Functions  Loops                                      Variables  \
# 0  ['nested_loop']      2                     ['print', 'arr', 'i', 'j']
# 1  ['bubble_sort']      2         ['n', 'i', 'len', 'range', 'arr', 'j']
# 2   ['merge_sort']      0  ['len', 'merge_sort', 'arr', 'L', 'R', 'mid']
# 3     ['find_max']      1                        ['max_val', 'arr', 'i']
# 4  ['nested_loop']      2                     ['print', 'arr', 'i', 'j']
#
#    Control_Flows                                             Tokens
# 0              0  [('ENCODING', 'utf-8'), ('NAME', 'def'), ('NAM...
# 1              1  [('ENCODING', 'utf-8'), ('NAME', 'def'), ('NAM...
# 2              1  [('ENCODING', 'utf-8'), ('NAME', 'def'), ('NAM...
# 3              1  [('ENCODING', 'utf-8'), ('NAME', 'def'), ('NAM...
# 4              0  [('ENCODING', 'utf-8'), ('NAME', 'def'), ('NAM...

# %%
new_df = pd.concat([ddf, analysis_results], axis=1)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# Initialize scalers and encoders
scaler = MinMaxScaler()
encoder = OneHotEncoder(sparse_output=False)

def extract_features_from_code(code_string, language="Python"):
    """
    Extract numerical and categorical features from the given code.
    """
    length = len(code_string)
    num_loops = code_string.count("for") + code_string.count("while")
    num_conditions = code_string.count("if") + code_string.count("elif") + code_string.count("else")
    num_functions = code_string.count("def ") + code_string.count("class ")
    num_variables = code_string.count("=")
    num_nested_loops = code_string.count("for ") + code_string.count("while ")
    num_recursive_calls = code_string.count("return")
    num_memory_allocations = code_string.count("append") + code_string.count("extend") + code_string.count("[")
    num_list_comprehensions = code_string.count("[") - code_string.count("append")  # Rough estimate
    nesting_depth = code_string.count("    ") // 4  # Assuming 4 spaces per indentation level
    
    # Additional complexity metric
    complexity_score = (num_loops * 2 + num_nested_loops * 3 + 
                        num_recursive_calls * 3 + num_memory_allocations * 2 +
                        num_list_comprehensions * 1.5)

    # Numerical features array
    numerical_features = np.array([
        length, num_loops, num_conditions, num_functions, num_variables,
        complexity_score, nesting_depth
    ]).reshape(1, -1)

    # Normalize numerical features
    numerical_features_scaled = scaler.fit_transform(numerical_features)

    # One-hot encode the programming language
    language_df = pd.DataFrame([[language]], columns=['Language'])
    language_encoded = encoder.fit_transform(language_df)
    
    # Combine numerical and categorical features
    final_features = np.hstack((numerical_features_scaled, language_encoded))

    print("Extracted Features (Scaled & Encoded):", final_features)  # Debugging
    return final_features

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# List of features to normalize
features_to_normalize = ['CPU_Time(ms)', 'Memory(KB)', 'Energy(kWh)', 'Carbon_Emission(gCO₂)']

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit and transform the selected features
new_df[features_to_normalize] = scaler.fit_transform(new_df[features_to_normalize])

# %%
new_df.to_csv('filename.csv', index=False)

# %%
# !pip install gym
# Out:
# Collecting gym
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      -------------- ------------------------- 262.1/721.7 kB ? eta -:--:--
#      --------------------------- ---------- 524.3/721.7 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 721.7/721.7 kB 1.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.18.0 in c:\users\deba prakash\anaconda3\lib\site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\deba prakash\anaconda3\lib\site-packages (from gym) (3.1.1)
# Collecting gym_notices>=0.0.4 (from gym)
#   Downloading gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827704 sha256=8e4fb5211eaa97b76b11028e4ec010378743842e98e2f4de81336a20d6fcab3d
#   Stored in directory: c:\users\deba prakash\appdata\local\pip\cache\wheels\95\51\6c\9bb05ebbe7c5cb8171dfaa3611f32622ca4658d53f31c79077
# Successfully built gym
# Installing collected packages: gym_notices, gym
# Successfully installed gym-0.26.2 gym_notices-0.0.8

# %%
# !pip show gym
# Out:
# Name: gym
# Version: 0.26.2
# Summary: Gym: A universal API for reinforcement learning environments
# Home-page: https://www.gymlibrary.dev/
# Author: Gym Community
# Author-email: jkterry@umd.edu
# License: MIT
# Location: C:\Users\Deba Prakash\anaconda3\Lib\site-packages
# Requires: cloudpickle, gym_notices, numpy
# Required-by:

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Deba Prakash\AppData\Local\Programs\Python\Python312\python.exe

# %%
!"{sys.executable}" -m pip install gym
# Out:
# Collecting gym
#   Using cached gym-0.26.2-py3-none-any.whl
# Requirement already satisfied: numpy>=1.18.0 in c:\users\deba prakash\appdata\local\programs\python\python312\lib\site-packages (from gym) (2.2.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\deba prakash\appdata\local\programs\python\python312\lib\site-packages (from gym) (3.1.1)
# Collecting gym_notices>=0.0.4 (from gym)
#   Using cached gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Installing collected packages: gym_notices, gym
# Successfully installed gym-0.26.2 gym_notices-0.0.8

# %%
import gym
import numpy as np
import pandas as pd

class CodeEfficiencyEnv(gym.Env):
    def __init__(self, df):
        super(CodeEfficiencyEnv, self).__init__()
        self.df = df
        self.index = 0
        
        # Define Action Space (0: Keep Code, 1: Suggest Optimization)
        self.action_space = gym.spaces.Discrete(2)

        # Define State Space (CPU_Time, Memory, Energy, Carbon_Emission, Loops, Control_Flows)
        self.observation_space = gym.spaces.Box(low=0, high=100000, shape=(6,), dtype=np.float32)

    def get_state(self):
        row = self.df.iloc[self.index]
        return np.array([row['CPU_Time(ms)'], row['Memory(KB)'], row['Energy(kWh)'],
                         row['Carbon_Emission(gCO₂)'], row['Loops'], row['Control_Flows']], dtype=np.float32)

    def step(self, action):
        reward = 0
        
        # If action = Efficiency_Label => Reward +1
        # If action != Efficiency_Label => Reward -1
        if action == self.df.iloc[self.index]['Efficiency_Label']:
            reward = 1
        else:
            reward = -1

        self.index += 1
        
        # Done when all rows are processed
        done = self.index >= len(self.df)
        
        if not done:
            state = self.get_state()
        else:
            state = None
        
        return state, reward, done, {}

    def reset(self):
        self.index = 0
        return self.get_state()

# %%
import gym
import numpy as np
import pandas as pd

# Load dataset
df = pd.read_csv(r"C:\Users\Deba Prakash\Desktop\Model Traning\final_dataset.csv")  # Use correct filename

# Initialize Environment
env = CodeEfficiencyEnv(df)
state = env.reset()
done = False

while not done:
    action = np.random.choice([0, 1])  # Random action
    state, reward, done, _ = env.step(action)
    print(f"Action: {action}, Reward: {reward}")
# Out:
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# ...
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 1, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
# Action: 0, Reward: -1
# Action: 0, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 0, Reward: 1
# Action: 1, Reward: 1
# Action: 1, Reward: -1
# Action: 1, Reward: -1
